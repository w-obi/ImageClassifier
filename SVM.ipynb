# %%
from imgPrep import procImg
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
import os

categories = ["cats", "dogs"]

print("Loading data...")
X_train, X_test, y_train, y_test = procImg(os.getenv("FOLDER_PATH"), categories, img_size=(64, 64), procType="svm")

print(f"Training Data Shape: {X_train.shape}")
print(f"Testing Data Shape: {X_test.shape}")

model = SVC(C=1.0, kernel='poly', degree=3, gamma='auto')

print("Training model...")
model.fit(X_train, y_train)

print("Evaluating...")
predictions = model.predict(X_test)

accuracy = accuracy_score(y_test, predictions)
print(f"Model Accuracy: {accuracy * 100:.2f}%")
# Out:
# Loading data...
# Training Data Shape: (1600, 1764)
# Testing Data Shape: (400, 1764)
# Training model...
# Evaluating...
# Model Accuracy: 46.75%
